# %% [markdown]
# # Folium - Codealong
#
# ## Introduction
#
# In this codealong, we'll take a look at how to create an interactive map using the Folium package. From there, we'll return to APIs in the final lab for the day where you'll make an interactive map from your requests to the API!
#
# ## Objectives
#
# You will be able to:
# * Create maps using Folium

# %% [markdown]
# ## Creating a Basemap
#
# Here we'll take a look at creating a basemap over the London region!

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/72/ff/004bfe344150a064e558cb2aedeaa02ecbf75e60e148a55a9198f0c41765/folium-0.10.0-py2.py3-none-any.whl (91kB)
#     100% |████████████████████████████████| 92kB 913kB/s ta 0:00:01
# Requirement already satisfied: jinja2>=2.9 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from requests->folium) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/johnnguyen/anaconda3/lib/python3.7/site-packages (from requests->folium) (1.24.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.10.0

# %%
import folium

lat = 51.51
long = -0.14

#Create a map of the area
base_map = folium.Map([lat, long], zoom_start=13)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding Markers to the Map
#
# Great! Now let's take a look at adding little markers to our map!
#
# **Note:** you may have to zoom out to see all of the markers!

# %%
import numpy as np

#Generate some random locations to add to our map
x = [lat + np.random.uniform(-.1,.1) for i in range(20)]
y = [long + np.random.uniform(-.1,.1) for i in range(20)]
points = list(zip(x, y))
for p in points:
    lat = p[0]
    long = p[1]
    marker = folium.Marker(location=[lat, long])
    marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Adding Pop-up Boxes to Our Markers
#
# Often we may wish to not only place markers on the map, but to create interactive pop-ups which display information to that location. To do this, we can add a popup to our markers when adding them to the map!

# %%
for p in points:
    lat = p[0]
    long = p[1]
    popup_text = "Latitude: {}, Longitude: {}".format(lat,long)
    popup = folium.Popup(popup_text, parse_html=True)
    marker = folium.Marker(location=[lat, long], popup=popup)
    marker.add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, if you click on the map markers, you should see a little information box pop up!
#
# ## Summary
#
# In this codealong, we learned how to use Folium to create some cool interactive maps with only a few lines of python code! In the next lab, you'll synthesize your skills for the day together and create an interactive visualization map for data you retrieve from the Yelp API!
